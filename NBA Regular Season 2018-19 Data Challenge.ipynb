# %% [markdown]
# # Nba Regular Season 2018-19 Data Challenge
#
# Your task will be to take the dataset given, and create an analysis answering the following 10 questions. This project will again test your knowledge of pandas in order to find the answers needed given the data you are presented with.

# %% [markdown]
# # What was the average age of player in the league?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

nba_stats = pd.read_csv('nbastats2018-2019.csv')
nba_stats.head()
# Out:
#            Name  Height  Weight                   Team  Age    Salary  Points  \
# 0  Alex Abrines      78     200  Oklahoma City Thunder   25   5455236     5.3
# 1    Quincy Acy      79     240           Phoenix Suns   28    213949     1.7
# 2  Jaylen Adams      74     190          Atlanta Hawks   22    236854     3.2
# 3  Steven Adams      84     265  Oklahoma City Thunder   25  24157304    13.9
# 4   Bam Adebayo      82     255             Miami Heat   21   2955840     8.9
#
#    Blocks  Steals  Assists  ...    MP   G   PER  OWS  DWS   WS   WS48   USG  \
# 0     0.2     0.5      0.6  ...  19.0  31   6.3  0.1  0.6  0.6  0.053  12.2
# 1     0.4     0.1      0.8  ...  12.3  10   2.9 -0.1  0.0 -0.1 -0.022   9.2
# 2     0.1     0.4      1.9  ...  12.6  34   7.6 -0.1  0.2  0.1  0.011  13.5
# 3     1.0     1.5      1.6  ...  33.4  80  18.5  5.1  4.0  9.1  0.163  16.4
# 4     0.8     0.9      2.2  ...  23.3  82  17.9  3.4  3.4  6.8  0.171  15.8
#
#    BPM  VORP
# 0 -3.4  -0.2
# ...

# %% [markdown]
# # What player scored the most points?

# %%
nba_stats_points = nba_stats.groupby(['Name', 'Points']).head()
nba_stats_points.sort_values('Points', ascending=False)

# James Harden had the most points
# Out:
#                       Name  Height  Weight                   Team  Age  \
# 202           James Harden      77     220        Houston Rockets   29
# 179            Paul George      81     220  Oklahoma City Thunder   28
# 15   Giannis Antetokounmpo      83     242        Milwaukee Bucks   24
# 151            Joel Embiid      84     250     Philadelphia 76ers   24
# 253           LeBron James      80     250     Los Angeles Lakers   34
# ..                     ...     ...     ...                    ...  ...
# 192         Donte Grantham      80     215                    NaN   23
# 242           Andre Ingram      75     190     Los Angeles Lakers   33
# 498            Okaro White      80     205     Washington Wizards   26
# 442           Kobi Simmons      77     166    Cleveland Cavaliers   21
# 14            Ike Anigbogu      82     250         Indiana Pacers   20
#
#        Salary  Points  Blocks  Steals  Assists  ...    MP   G   PER   OWS  \
# ...

# %% [markdown]
# # What player had the most blocks during the season? Was it a post player (F/C)?

# %%
nba_stats_blocks = nba_stats.groupby('Name')['Blocks'].max().sort_values(ascending=False)
nba_stats_blocks
# Out:
# Name
# Myles Turner             2.7
# Anthony Davis            2.4
# Mitchell Robinson        2.4
# Rudy Gobert              2.3
# Brook Lopez              2.2
#                         ...
# Sviatoslav Mykhailiuk    0.0
# Furkan Korkmaz           0.0
# Frank Jackson            0.0
# Matthew Dellavedova      0.0
# Zhou Qi                  0.0
# Name: Blocks, Length: 521, dtype: float64

# %% [markdown]
# # Based on the regular season, who had the best chance to win a title given their win percentage?

# %%
# I do not see a stat that corresponds to the win percentage here.  I don't even see the stats needed for the formula of
# W / GP.  

# If the columns needed were there, the code would be:

# nba_stats['Win%'] = nba_stats['W'] / nba_stats['GP']

# nba_stats_Win_per = nba_stats_win_per.groupby(['Name', 'Win%']).head()

# nba_stats_Win_per
# Out:
# Index(['Name', 'Height', 'Weight', 'Team', 'Age', 'Salary', 'Points', 'Blocks',
#        'Steals', 'Assists', 'Rebounds', 'FT%', 'FTA', 'FG3%', 'FG3A', 'FG%',
#        'FGA', 'MP', 'G', 'PER', 'OWS', 'DWS', 'WS', 'WS48', 'USG', 'BPM',
#        'VORP'],
#       dtype='object')

# %% [markdown]
# # What player had the best 3-pt percentage?

# %%
nba_stats_3pt = nba_stats.sort_values(by='FG3%', ascending=False).filter(['Name', 'FG3%'])
nba_stats_3pt.head(5)
# Out:
#               Name   FG3%
# 312  Scott Machado  1.000
# 439  Jordan Sibert  1.000
# 147   Trevon Duval  1.000
# 352  Eric Moreland  1.000
# 95    Troy Caupain  0.667

# %%
nba_stats.keys()
# Out:
# Index(['Name', 'Height', 'Weight', 'Team', 'Age', 'Salary', 'Points', 'Blocks',
#        'Steals', 'Assists', 'Rebounds', 'FT%', 'FTA', 'FG3%', 'FG3A', 'FG%',
#        'FGA', 'MP', 'G', 'PER', 'OWS', 'DWS', 'WS', 'WS48', 'USG', 'BPM',
#        'VORP'],
#       dtype='object')

# %% [markdown]
# # Who played the most minutes during the season

# %%
nba_stats_MP = nba_stats.sort_values(by='MP', ascending=False).filter(['Name', 'MP'])
nba_stats_MP.head(5)
# Out:
#                   Name    MP
# 179        Paul George  36.9
# 37        Bradley Beal  36.9
# 202       James Harden  36.8
# 496  Russell Westbrook  36.0
# 226       Jrue Holiday  35.9

# %% [markdown]
# # What player given their player effiecency rating was the clutchest during the season?

# %%
nba_stats_win_percentage = nba_stats.groupby('Name')['PER'].max().sort_values(ascending=False)
nba_stats_win_percentage

# Zhou Qi had the highest PER.
# Out:
# Name
# Zhou Qi                  80.4
# Trevon Duval             38.3
# Gary Payton II           36.9
# Alan Williams            32.9
# Giannis Antetokounmpo    30.9
#                          ...
# Okaro White              -4.5
# Ike Anigbogu             -6.0
# Andre Ingram            -11.9
# Terrence Jones          -15.8
# Donte Grantham          -38.1
# Name: PER, Length: 521, dtype: float64

# %% [markdown]
# # What team had the youngest roster?

# %%
nba_stats_youngest = nba_stats.groupby('Team')['Age'].mean().sort_values()

nba_stats_youngest
# Out:
# Team
# Chicago Bulls             24.312500
# Sacramento Kings          24.400000
# Orlando Magic             24.533333
# New York Knicks           24.625000
# Phoenix Suns              24.761905
# Portland Trail Blazers    24.857143
# Indiana Pacers            25.058824
# Denver Nuggets            25.266667
# Brooklyn Nets             25.555556
# Boston Celtics            25.600000
# Memphis Grizzlies         25.647059
# Oklahoma City Thunder     25.750000
# New Orleans Pelicans      25.777778
# Cleveland Cavaliers       26.000000
# Charlotte Hornets         26.000000
# Detroit Pistons           26.266667
# Philadelphia 76ers        26.352941
# Atlanta Hawks             26.476190
# Los Angeles Lakers        26.625000
# Minnesota Timberwolves    26.625000
# Washington Wizards        26.764706
# Milwaukee Bucks           26.928571
# Los Angeles Clippers      27.105263
# Utah Jazz                 27.133333
# Toronto Raptors           27.166667
# Golden State Warriors     27.866667
# ...

# %%
nba_stats.keys()
# Out:
# Index(['Name', 'Height', 'Weight', 'Team', 'Age', 'Salary', 'Points', 'Blocks',
#        'Steals', 'Assists', 'Rebounds', 'FT%', 'FTA', 'FG3%', 'FG3A', 'FG%',
#        'FGA', 'MP', 'G', 'PER', 'OWS', 'DWS', 'WS', 'WS48', 'USG', 'BPM',
#        'VORP'],
#       dtype='object')

# %% [markdown]
# # Who is the highest paid player during the seasion?

# %%
# nba_stats_salary = nba_stats.groupby('Name')['Salary'].max().sort_values()
# nba_stats_salary

# I had to convert the Salary data to numeric as it was reading for this code as a string
nba_stats['Salary'] = pd.to_numeric(nba_stats['Salary'], errors='coerce')

nba_stats_salary = nba_stats.groupby('Name')['Salary'].max().sort_values(ascending=False)

nba_stats_salary.head(15)
# Out:
# Name
# Stephen Curry        37457154.0
# Chris Paul           35654150.0
# LeBron James         35654150.0
# Russell Westbrook    35654150.0
# Blake Griffin        32088932.0
# Gordon Hayward       31214295.0
# Kyle Lowry           31200000.0
# Paul George          30560700.0
# Mike Conley          30521116.0
# James Harden         30431854.0
# Kevin Durant         30000000.0
# Paul Millsap         29730769.0
# Al Horford           28928710.0
# Damian Lillard       27977689.0
# DeMar DeRozan        27739975.0
# Name: Salary, dtype: float64

# %% [markdown]
# # At the end of a game, who WOULDN'T you want on the Free Throw Line?

# %%
nba_stats_free_throw = nba_stats.groupby(['Name', 'FT%', 'FTA']).min()

nba_stats_free_throw.sort_values('FT%', ascending=True)
# Out:
#                             Height  Weight                   Team  Age  \
# Name               FT% FTA
# Jacob Evans        0.0 0.0      78     210  Golden State Warriors   21
# Tahjere McCall     0.0 1.0      77     195          Brooklyn Nets   24
# Terrence Jones     0.0 0.5      81     252        Houston Rockets   27
# Donatas Motiejunas 0.0 0.7      84     222      San Antonio Spurs   28
# Haywood Highsmith  0.0 0.4      79     220                    NaN   22
# ...                            ...     ...                    ...  ...
# Jimmer Fredette    1.0 1.0      74     195           Phoenix Suns   29
# Gary Clark         1.0 0.1      80     225                    NaN   24
# Kalin Lucas        1.0 2.0      73     195                    NaN   29
# Dusty Hannahs      1.0 1.0      75     210      Memphis Grizzlies   25
# Tyler Cavanaugh    1.0 0.2      81     238                    NaN   24
#
#                                Salary  Points  Blocks  Steals  Assists  \
# ...
